# %%
import spotipy
import sys
import time
import json
from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='ccae2e7a3a0f48088d24563289eb71d0', client_secret='0204fbff5f2c438a816b7c01ede9d9ce')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
artist_name = 'weezer'

results = sp.search(q=artist_name, limit=10)
tids = []
for i, t in enumerate(results['tracks']['items']):
    print(t['name'])
    tids.append(t['uri'])

start = time.time()
features = pd.DataFrame(sp.audio_features(tids))
features
#delta = time.time() - start
# for feature in features:
#     print(json.dumps(feature, indent=4))
#     print()
#     analysis = sp._get(feature['analysis_url'])
#     print(json.dumps(analysis, indent=4))
#     print()
# print ("features retrieved in %.2f seconds" % (delta,))
# Out:
# Island In The Sun
# Say It Ain't So
# Buddy Holly
# Feels Like Summer
# Beverly Hills
# Hash Pipe
# Say It Ain't So
# Undone - The Sweater Song
# Happy Hour - Lefti Remix
# Thank God For Girls
#    acousticness                                       analysis_url  \
# 0      0.010800  https://api.spotify.com/v1/audio-analysis/2MLH...
# 1      0.003280  https://api.spotify.com/v1/audio-analysis/4YPh...
# 2      0.006110  https://api.spotify.com/v1/audio-analysis/7Gpt...
# 3      0.020000  https://api.spotify.com/v1/audio-analysis/2jz1...
# 4      0.107000  https://api.spotify.com/v1/audio-analysis/1yKu...
# 5      0.000119  https://api.spotify.com/v1/audio-analysis/2mPM...
# 6      0.007170  https://api.spotify.com/v1/audio-analysis/6VoI...
# 7      0.005560  https://api.spotify.com/v1/audio-analysis/6Fxb...
# 8      0.010500  https://api.spotify.com/v1/audio-analysis/2GF1...
# 9      0.047400  https://api.spotify.com/v1/audio-analysis/5uyw...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.646       200307   0.778  2MLHyLy5z5l5YRp7momlgw
# 1         0.635       256880   0.435  4YPhn26bIFm2KUkL1VLzQG
# 2         0.535       159587   0.931  7GptbanebPZYkLPvjNfd6m
# 3         0.530       195893   0.867  2jz1bw1p0WQj0PDnVDP0uY
# 4         0.542       196093   0.819  1yKu2MhpwzDXXH2tzG6xoa
# 5         0.582       186533   0.880  2mPMFJvQ0v27gVqe5b6nDn
# 6         0.624       258827   0.517  6VoIBz0VhCyz7OdEoRYDiA
# 7         0.450       304987   0.652  6FxbwB6o1MKOy0dHvxNr2W
# 8         0.674       176404   0.710  2GF17tJAm3hvx7MEkO4Vbv
# 9         0.559       210187   0.876  5uywMR3hTeVPoWaFDSliJb
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.006540    4    0.1440    -6.222     0       0.0273  114.647
# 1          0.000007    3    0.0710    -7.521     1       0.0310   76.098
# 2          0.000073    8    0.0887    -4.012     1       0.0451  120.958
# 3          0.000248   11    0.7370    -4.989     1       0.0504  175.981
# 4          0.000000    5    0.1870    -3.735     1       0.1610  175.711
# 5          0.335000    7    0.2790    -6.242     1       0.0470  125.584
# 6          0.000014    3    0.0687    -7.122     1       0.0322  151.695
# 7          0.000786    6    0.0933    -5.541     1       0.0276   80.128
# 8          0.000002    5    0.3740    -7.051     0       0.0454  112.004
# 9          0.000000    4    0.0734    -6.479     0       0.0495   95.070
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/2MLHyLy5z5l5...
# 1               4  https://api.spotify.com/v1/tracks/4YPhn26bIFm2...
# 2               4  https://api.spotify.com/v1/tracks/7GptbanebPZY...
# 3               4  https://api.spotify.com/v1/tracks/2jz1bw1p0WQj...
# 4               4  https://api.spotify.com/v1/tracks/1yKu2MhpwzDX...
# 5               4  https://api.spotify.com/v1/tracks/2mPMFJvQ0v27...
# 6               4  https://api.spotify.com/v1/tracks/6VoIBz0VhCyz...
# 7               4  https://api.spotify.com/v1/tracks/6FxbwB6o1MKO...
# 8               4  https://api.spotify.com/v1/tracks/2GF17tJAm3hv...
# 9               4  https://api.spotify.com/v1/tracks/5uywMR3hTeVP...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:2MLHyLy5z5l5YRp7momlgw    0.782
# 1  audio_features  spotify:track:4YPhn26bIFm2KUkL1VLzQG    0.459
# 2  audio_features  spotify:track:7GptbanebPZYkLPvjNfd6m    0.825
# 3  audio_features  spotify:track:2jz1bw1p0WQj0PDnVDP0uY    0.740
# 4  audio_features  spotify:track:1yKu2MhpwzDXXH2tzG6xoa    0.714
# 5  audio_features  spotify:track:2mPMFJvQ0v27gVqe5b6nDn    0.527
# 6  audio_features  spotify:track:6VoIBz0VhCyz7OdEoRYDiA    0.420
# 7  audio_features  spotify:track:6FxbwB6o1MKOy0dHvxNr2W    0.514
# 8  audio_features  spotify:track:2GF17tJAm3hvx7MEkO4Vbv    0.684
# 9  audio_features  spotify:track:5uywMR3hTeVPoWaFDSliJb    0.400
