# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
latin_df = pd.read_csv('data/latin_db.csv', sep=';')
electronic_df = pd.read_csv('data/electronic_db.csv', sep=';')
rap_df = pd.read_csv('data/rap_db.csv', sep=';')
metal_df = pd.read_csv('data/metal_db.csv', sep=';')
rock_df = pd.read_csv('data/rock_db.csv', sep=';')
pop_df = pd.read_csv('data/pop_db.csv', sep=';')
rb_df = pd.read_csv('data/r&b_db.csv', sep=';')
country_df = pd.read_csv('data/country_db.csv', sep=';')
folk_df = pd.read_csv('data/folk_db.csv', sep=';')
jazz_df = pd.read_csv('data/jazz_db.csv', sep=';')

# %%
df = pd.concat([latin_df, electronic_df, rap_df, metal_df, rock_df, pop_df, rb_df, country_df, folk_df, jazz_df])
df.reset_index(drop=True, inplace=True)
df.drop_duplicates(subset=['id'], inplace=True)
df.head()
# Out:
#                                  name       artist  genre  acousticness  \
# 0                            Mi Gente     J Balvin  latin        0.0164
# 1                   Despacito - Remix   Luis Fonsi  latin        0.2220
# 2                           Me Rehúso  Danny Ocean  latin        0.0231
# 3  Despacito (Featuring Daddy Yankee)   Luis Fonsi  latin        0.2000
# 4                              Bonita     J Balvin  latin        0.0116
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/4ipn...         0.535
# 1  https://api.spotify.com/v1/audio-analysis/6rPO...         0.630
# 2  https://api.spotify.com/v1/audio-analysis/6De0...         0.744
# 3  https://api.spotify.com/v1/audio-analysis/7CUY...         0.618
# 4  https://api.spotify.com/v1/audio-analysis/0atf...         0.782
#
#    duration_ms  energy                      id  instrumentalness   ...    \
# 0       189440   0.678  4ipnJyDU3Lq15qBAYNqlqK          0.000013   ...
# 1       228827   0.815  6rPO02ozF3bM7NnOV4h6s2          0.000000   ...
# 2       205715   0.804  6De0lHrwBfPfrhorm9q1Xl          0.000000   ...
# 3       228200   0.793  7CUYHcu0RnbOnMz4RuN07w          0.000000   ...
# 4       265747   0.864  0atfY1ew83Ql9nNnJiD2t5          0.002680   ...
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  \
# 0    0.1280    -4.906     0       0.0998  102.681               4
# 1    0.0910    -4.265     1       0.1520   88.357               4
# 2    0.0494    -6.327     1       0.0677  104.823               4
# 3    0.1060    -4.777     1       0.1510   88.387               4
# 4    0.2920    -1.749     0       0.0402   96.049               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/4ipnJyDU3Lq1...  audio_features
# 1  https://api.spotify.com/v1/tracks/6rPO02ozF3bM...  audio_features
# 2  https://api.spotify.com/v1/tracks/6De0lHrwBfPf...  audio_features
# 3  https://api.spotify.com/v1/tracks/7CUYHcu0RnbO...  audio_features
# 4  https://api.spotify.com/v1/tracks/0atfY1ew83Ql...  audio_features
#
#                                     uri valence
# 0  spotify:track:4ipnJyDU3Lq15qBAYNqlqK   0.287
# 1  spotify:track:6rPO02ozF3bM7NnOV4h6s2   0.813
# 2  spotify:track:6De0lHrwBfPfrhorm9q1Xl   0.426
# 3  spotify:track:7CUYHcu0RnbOnMz4RuN07w   0.874
# 4  spotify:track:0atfY1ew83Ql9nNnJiD2t5   0.866
#
# [5 rows x 21 columns]

# %% [markdown]
# According to Spotify's metric this song is 100% happy

# %%
df[df['valence'] == 1]
# Out:
#                         name                                         artist  \
# 28280               La Suata  La Arrolladora Banda El Limón De Rene Camacho
# 28408  La Suata - Vers.Radio  La Arrolladora Banda El Limón De Rene Camacho
#
#        genre  acousticness                                       analysis_url  \
# 28280  latin         0.408  https://api.spotify.com/v1/audio-analysis/4UTW...
# 28408  latin         0.396  https://api.spotify.com/v1/audio-analysis/5F1m...
#
#        danceability  duration_ms  energy                      id  \
# 28280         0.565       146413   0.785  4UTWOEGDH7LphJhRuxWwnB
# 28408         0.568       146907   0.864  5F1mVGJP0CcShmTHXjc3VN
#
#        instrumentalness   ...    liveness  loudness  mode  speechiness  \
# 28280               0.0   ...       0.314    -3.449     1       0.0477
# 28408               0.0   ...       0.307    -0.300     1       0.0428
#
#          tempo  time_signature  \
# 28280  149.724               4
# 28408  149.671               4
#
#                                               track_href            type  \
# 28280  https://api.spotify.com/v1/tracks/4UTWOEGDH7Lp...  audio_features
# 28408  https://api.spotify.com/v1/tracks/5F1mVGJP0CcS...  audio_features
#
#                                         uri valence
# 28280  spotify:track:4UTWOEGDH7LphJhRuxWwnB     1.0
# 28408  spotify:track:5F1mVGJP0CcShmTHXjc3VN     1.0
#
# [2 rows x 21 columns]

# %% [markdown]
# Whether these ones are 100% sad. Most of them are skit's or short parts, normally intros, reprises or outros.

# %%
df[df['valence'] == 0]
# Out:
#                                                      name  \
# 74729                                   This DJ Will Self
# 74738                                                 Yes
# 74996                                       Tight Sweater
# 74997                                       Tight Sweater
# 82067   Where Are You? - Ringtone; 2017 Remastered Ver...
# 82752                                              Circus
# 82753                                              Circus
# 87065                                               Intro
# 87124                                        Is He Ready?
# 87978                                   Max Julien Jacket
# 88097                                               Intro
# 89999                                                 CAT
# 175667                                         Sacrificed
# 188829                         Ping Again (Live in Japan)
# 194572                                     Skody's Coming
# 199800                               Ping (Live in Japan)
# 283191                                             Higher
# 341395                                              ドゥカティ
# 342151                                     Voice Memo 162
# 343067                                    So In Love Skit
# 343241             Figure It Out - Call Out Research Hook
# 343474                                              ドゥカティ
# 344197                                        Love Part 2
# 344228                                   Lame (Interlude)
# 344786                                    Dj Drama Speakz
# 358639                                  Ride Me Down Easy
# 396552                               Shatner Says Goodbye
# 399438                                   So Are You To Me
# 423452                                  "Fox News" Banter
# 431233                                          Departure
# 443721            Angels We Have Heard On High Commentary
# 449384                   I've Got My Love To Keep Me Warm
# 449444                              It's Easy To Remember
# 459431                 Back In Your Own Backyard - Take 1
# 462341                                         By Strauss
# 478992                                       Weep No More
# 481611                            I Get A Kick Out Of You
# 483130                                 My Melancholy Baby
# 483140                                       Confirmation
# 483141                                       Confirmation
# 483191                                       Confirmation
# 483937                                       Confirmation
# 484447  Blues (Fast) - Abandoned Take, Studio Chatter ...
# 486694                           I’m In The Mood For Love
# 491941                                   A Sunbonnet Blue
# 492471  Introduction To Miles Ahead Medley - Live Version
#
#                         artist       genre  acousticness  \
# 74729           Paul Oakenfold  electronic       0.31600
# 74738                 Uberzone  electronic       0.00000
# 74996                   Moloko  electronic       0.70600
# 74997                   Moloko  electronic       0.70600
# 82067            Pet Shop Boys  electronic       0.85300
# 82752                   Moloko  electronic       0.52800
# 82753                   Moloko  electronic       0.52800
# 87065            Basement Jaxx  electronic       0.22600
# 87124               Mr. Scruff  electronic       0.94400
# 87978                Moodymann  electronic       0.93000
# 88097            Basement Jaxx  electronic       0.20800
# 89999            Mouse On Mars  electronic       0.95800
# 175667            Napalm Death       metal       0.00165
# 188829         Nuclear Assault       metal       0.09600
# 194572                 Warlord       metal       0.00751
# 199800         Nuclear Assault       metal       0.04170
# 283191                 Rihanna         pop       0.15400
# 341395                    Tyga         r&b       0.69000
# 342151                     NAO         r&b       0.27300
# 343067       Chrisette Michele         r&b       0.34300
# 343241         Kenny Lattimore         r&b       0.48400
# 343474                    Tyga         r&b       0.63900
# 344197           Janet Jackson         r&b       0.19900
# 344228           Janet Jackson         r&b       0.35000
# 344786                DJ Drama         r&b       0.00417
# 358639         Waylon Jennings     country       0.75600
# 396552            Brad Paisley     country       0.37400
# 399438       Eastmountainsouth        folk       0.94900
# 423452           Antje Duvekot        folk       0.80700
# 431233         The Moody Blues        folk       0.71900
# 443721         Sarah McLachlan        folk       0.42600
# 449384          Billie Holiday        jazz       0.84500
# 449444   John Coltrane Quartet        jazz       0.93800
# 459431          Billie Holiday        jazz       0.89000
# 462341         Ella Fitzgerald        jazz       0.67200
# 478992            Dave Brubeck        jazz       0.94300
# 481611  Charlie Parker Quintet        jazz       0.86100
# 483130          Charlie Parker        jazz       0.92100
# 483140  Charlie Parker Quartet        jazz       0.76400
# 483141  Charlie Parker Quartet        jazz       0.93000
# 483191  Charlie Parker Quartet        jazz       0.83100
# 483937  Charlie Parker Quartet        jazz       0.75700
# 484447  Charlie Parker Quartet        jazz       0.81800
# 486694            Julie London        jazz       0.94700
# 491941          Billie Holiday        jazz       0.94800
# 492471             Miles Davis        jazz       0.70400
#
#                                              analysis_url  danceability  \
# 74729   https://api.spotify.com/v1/audio-analysis/1qwQ...         0.000
# 74738   https://api.spotify.com/v1/audio-analysis/1dAe...         0.000
# 74996   https://api.spotify.com/v1/audio-analysis/3a8I...         0.353
# 74997   https://api.spotify.com/v1/audio-analysis/40Ga...         0.353
# 82067   https://api.spotify.com/v1/audio-analysis/3iIx...         0.367
# 82752   https://api.spotify.com/v1/audio-analysis/50yT...         0.436
# 82753   https://api.spotify.com/v1/audio-analysis/32am...         0.436
# 87065   https://api.spotify.com/v1/audio-analysis/7Bhq...         0.448
# 87124   https://api.spotify.com/v1/audio-analysis/3iTj...         0.519
# 87978   https://api.spotify.com/v1/audio-analysis/3y5Y...         0.669
# 88097   https://api.spotify.com/v1/audio-analysis/4ttI...         0.443
# 89999   https://api.spotify.com/v1/audio-analysis/7jwX...         0.304
# 175667  https://api.spotify.com/v1/audio-analysis/4zjJ...         0.000
# 188829  https://api.spotify.com/v1/audio-analysis/6eEn...         0.255
# 194572  https://api.spotify.com/v1/audio-analysis/4RFz...         0.220
# 199800  https://api.spotify.com/v1/audio-analysis/41Wj...         0.540
# 283191  https://api.spotify.com/v1/audio-analysis/2XoH...         0.000
# 341395  https://api.spotify.com/v1/audio-analysis/2pX6...         0.478
# 342151  https://api.spotify.com/v1/audio-analysis/4hhK...         0.000
# 343067  https://api.spotify.com/v1/audio-analysis/4O5X...         0.000
# 343241  https://api.spotify.com/v1/audio-analysis/1NWd...         0.000
# 343474  https://api.spotify.com/v1/audio-analysis/7zCp...         0.478
# 344197  https://api.spotify.com/v1/audio-analysis/0XDC...         0.000
# 344228  https://api.spotify.com/v1/audio-analysis/5odv...         0.000
# 344786  https://api.spotify.com/v1/audio-analysis/6Boy...         0.000
# 358639  https://api.spotify.com/v1/audio-analysis/2mex...         0.000
# 396552  https://api.spotify.com/v1/audio-analysis/37ou...         0.624
# 399438  https://api.spotify.com/v1/audio-analysis/5IGY...         0.000
# 423452  https://api.spotify.com/v1/audio-analysis/7sqL...         0.000
# 431233  https://api.spotify.com/v1/audio-analysis/3JJc...         0.000
# 443721  https://api.spotify.com/v1/audio-analysis/23QW...         0.000
# 449384  https://api.spotify.com/v1/audio-analysis/64jo...         0.000
# 449444  https://api.spotify.com/v1/audio-analysis/393l...         0.000
# 459431  https://api.spotify.com/v1/audio-analysis/09eD...         0.000
# 462341  https://api.spotify.com/v1/audio-analysis/0O4u...         0.000
# 478992  https://api.spotify.com/v1/audio-analysis/60zC...         0.000
# 481611  https://api.spotify.com/v1/audio-analysis/6zMh...         0.625
# 483130  https://api.spotify.com/v1/audio-analysis/5HAJ...         0.000
# 483140  https://api.spotify.com/v1/audio-analysis/6Afb...         0.000
# 483141  https://api.spotify.com/v1/audio-analysis/4ZoQ...         0.000
# 483191  https://api.spotify.com/v1/audio-analysis/61lK...         0.000
# 483937  https://api.spotify.com/v1/audio-analysis/57Bn...         0.000
# 484447  https://api.spotify.com/v1/audio-analysis/62Kh...         0.000
# 486694  https://api.spotify.com/v1/audio-analysis/3Mwr...         0.000
# 491941  https://api.spotify.com/v1/audio-analysis/3HEd...         0.000
# 492471  https://api.spotify.com/v1/audio-analysis/6n5h...         0.000
#
#         duration_ms  energy                      id  instrumentalness   ...    \
# 74729         11600  0.4560  1qwQtXD5fLTQSENK5mYLMo          0.082900   ...
# 74738          9787  0.0000  1dAeQH3kMq2oSQd4GaAXVV          0.000000   ...
# 74996         15320  0.2320  3a8IXw3migbG20f3w6c3Vm          0.000025   ...
# 74997         15320  0.2320  40GaJYtHqM7pXEovHHKR7P          0.000025   ...
# 82067         18333  0.1790  3iIxWMLGGOPF3OO3eLkGZx          0.940000   ...
# 82752         19373  0.0298  50yTNsvZfxouRpla1ipM1n          0.926000   ...
# 82753         19373  0.0298  32amggi74u8yF228OrDIHw          0.926000   ...
# 87065         19360  0.1060  7BhqZnNRDCp1xvYojeAjVg          0.925000   ...
# 87124         16467  0.1870  3iTj3jTuR7bZjduagnJTeY          0.000016   ...
# 87978         16480  0.4780  3y5Y48rX9waA9gkhKlDkPu          0.000000   ...
# 88097         19693  0.1050  4ttIJZW4oHqLEDa9ECA2Xe          0.932000   ...
# 89999         17653  0.3400  7jwXiUgYPB0faCm9MsImcg          0.573000   ...
# 175667        66427  0.9620  4zjJ9fVE6ZWH5pffeEaQdK          0.878000   ...
# 188829        15280  0.2830  6eEnpwdNi4mbhUxxY786bj          0.000752   ...
# 194572        16800  0.7840  4RFzVh4zwGcKsUdE55ro2H          0.930000   ...
# 199800        15480  0.4950  41WjqvUKEMQDDUzk8UWxvy          0.973000   ...
# 283191       120627  0.5540  2XoHcqzQeKau0wrqFk7gX0          0.000000   ...
# 283191  https://api.spotify.com/v1/tracks/2XoHcqzQeKau...  audio_features
# 341395  https://api.spotify.com/v1/tracks/2pX6s69eA2h8...  audio_features
# 342151  https://api.spotify.com/v1/tracks/4hhKtWh8y1dn...  audio_features
# 343067  https://api.spotify.com/v1/tracks/4O5X2tfPI0qB...  audio_features
# 343241  https://api.spotify.com/v1/tracks/1NWdY9Hahmfe...  audio_features
# 343474  https://api.spotify.com/v1/tracks/7zCpJKA4Flh1...  audio_features
# 344197  https://api.spotify.com/v1/tracks/0XDCiQU4FfR8...  audio_features
# 344228  https://api.spotify.com/v1/tracks/5odvwhJNoyWK...  audio_features
# 344786  https://api.spotify.com/v1/tracks/6BoyLhP10KA5...  audio_features
# 358639  https://api.spotify.com/v1/tracks/2mex2o4uA69p...  audio_features
# 396552  https://api.spotify.com/v1/tracks/37ouHVWsgU2F...  audio_features
# 399438  https://api.spotify.com/v1/tracks/5IGYPdHMSG4P...  audio_features
# 423452  https://api.spotify.com/v1/tracks/7sqLjB97Eib6...  audio_features
# 431233  https://api.spotify.com/v1/tracks/3JJc7ADYySnb...  audio_features
# 443721  https://api.spotify.com/v1/tracks/23QWzt7P4VhX...  audio_features
# 449384  https://api.spotify.com/v1/tracks/64joHLzdHU7Z...  audio_features
# 449444  https://api.spotify.com/v1/tracks/393l7z9O3iQl...  audio_features
# 459431  https://api.spotify.com/v1/tracks/09eDRV4nzC3e...  audio_features
# 462341  https://api.spotify.com/v1/tracks/0O4uJVHqn36S...  audio_features
# 478992  https://api.spotify.com/v1/tracks/60zChNKZzASX...  audio_features
# 481611  https://api.spotify.com/v1/tracks/6zMhlyDtxJ47...  audio_features
# 483130  https://api.spotify.com/v1/tracks/5HAJC4cKIvXw...  audio_features
# 483140  https://api.spotify.com/v1/tracks/6AfbYUcZCXzO...  audio_features
# 483141  https://api.spotify.com/v1/tracks/4ZoQjHkwGasP...  audio_features
# 483191  https://api.spotify.com/v1/tracks/61lKVGpZtNw4...  audio_features
# 483937  https://api.spotify.com/v1/tracks/57BneO4Ejd32...  audio_features
# 484447  https://api.spotify.com/v1/tracks/62KhcwQl1n9W...  audio_features
# 486694  https://api.spotify.com/v1/tracks/3MwrUltRkhv3...  audio_features
# 491941  https://api.spotify.com/v1/tracks/3HEdglBjJiGe...  audio_features
# 492471  https://api.spotify.com/v1/tracks/6n5hjncDPR26...  audio_features
#
#                                          uri valence
# 74729   spotify:track:1qwQtXD5fLTQSENK5mYLMo     0.0
# 74738   spotify:track:1dAeQH3kMq2oSQd4GaAXVV     0.0
# 74996   spotify:track:3a8IXw3migbG20f3w6c3Vm     0.0
# 74997   spotify:track:40GaJYtHqM7pXEovHHKR7P     0.0
# 82067   spotify:track:3iIxWMLGGOPF3OO3eLkGZx     0.0
# 82752   spotify:track:50yTNsvZfxouRpla1ipM1n     0.0
# 82753   spotify:track:32amggi74u8yF228OrDIHw     0.0
# 87065   spotify:track:7BhqZnNRDCp1xvYojeAjVg     0.0
# 87124   spotify:track:3iTj3jTuR7bZjduagnJTeY     0.0
# 87978   spotify:track:3y5Y48rX9waA9gkhKlDkPu     0.0
# 88097   spotify:track:4ttIJZW4oHqLEDa9ECA2Xe     0.0
# 89999   spotify:track:7jwXiUgYPB0faCm9MsImcg     0.0
# 175667  spotify:track:4zjJ9fVE6ZWH5pffeEaQdK     0.0
# 188829  spotify:track:6eEnpwdNi4mbhUxxY786bj     0.0
# 194572  spotify:track:4RFzVh4zwGcKsUdE55ro2H     0.0
# 199800  spotify:track:41WjqvUKEMQDDUzk8UWxvy     0.0
# 283191  spotify:track:2XoHcqzQeKau0wrqFk7gX0     0.0
# 341395  spotify:track:2pX6s69eA2h8z6f6pBvs5u     0.0
# 342151  spotify:track:4hhKtWh8y1dnwEHJU9X1WJ     0.0
# 343067  spotify:track:4O5X2tfPI0qBbRcqZHXXQr     0.0
# 343241  spotify:track:1NWdY9HahmfemEC3bzegBP     0.0
# 343474  spotify:track:7zCpJKA4Flh1jbcr16055t     0.0
# 344197  spotify:track:0XDCiQU4FfR84ihVaa0Mgo     0.0
# 344228  spotify:track:5odvwhJNoyWKATVwD17tFv     0.0
# 344786  spotify:track:6BoyLhP10KA5iLcaTnz3ZJ     0.0
# 358639  spotify:track:2mex2o4uA69pMcLjMtyyGb     0.0
# 396552  spotify:track:37ouHVWsgU2F5jWWJec6X1     0.0
# 399438  spotify:track:5IGYPdHMSG4PLXDS9LDPJS     0.0
# 423452  spotify:track:7sqLjB97Eib6kdwKA2Hixp     0.0
# 431233  spotify:track:3JJc7ADYySnbRhtdkFhMdG     0.0
# 443721  spotify:track:23QWzt7P4VhXC41zfULReK     0.0
# 449384  spotify:track:64joHLzdHU7ZYFedwSL3k9     0.0
# 449444  spotify:track:393l7z9O3iQlA6uQj0Iejb     0.0
# 459431  spotify:track:09eDRV4nzC3eVX7tDEJUNb     0.0
# 462341  spotify:track:0O4uJVHqn36ScFIBXd2zdc     0.0
# 478992  spotify:track:60zChNKZzASXYEqREynXT2     0.0
# 481611  spotify:track:6zMhlyDtxJ47iOZ1bQ49p1     0.0
# 483130  spotify:track:5HAJC4cKIvXwO8zjM1TNw7     0.0
# 483140  spotify:track:6AfbYUcZCXzOHrozuya2nT     0.0
# 483141  spotify:track:4ZoQjHkwGasPXcIX7Aqnd7     0.0
# 483191  spotify:track:61lKVGpZtNw4w4TYpjmrqe     0.0
# 483937  spotify:track:57BneO4Ejd32LqK7hLn1Dg     0.0
# 484447  spotify:track:62KhcwQl1n9WWDsxhyeCNj     0.0
# 486694  spotify:track:3MwrUltRkhv39mg6OsJxsi     0.0
# 491941  spotify:track:3HEdglBjJiGeWAExZeWZ22     0.0
# 492471  spotify:track:6n5hjncDPR26iEOxQu5DGh     0.0
#
# [46 rows x 21 columns]

# %%
danceability = df.groupby('genre')['danceability'].mean()
duration_s = df.groupby('genre')['duration_ms'].mean() / 1000
energy = df.groupby('genre')['energy'].mean()
instrumentalness = df.groupby('genre')['instrumentalness'].mean()
key = df.groupby('genre')['key'].agg(lambda x:x.value_counts().index[0]) #mode
loudness = df.groupby('genre')['loudness'].mean()
mode = df.groupby('genre')['mode'].agg(lambda x:x.value_counts().index[0]) #mode
speechiness = df.groupby('genre')['speechiness'].mean()
tempo = df.groupby('genre')['tempo'].mean()
time_signature = df.groupby('genre')['time_signature'].agg(lambda x:x.value_counts().index[0]) #mode
valence = df.groupby('genre')['valence'].mean()

# %%
danceability.sort_values(ascending=False, inplace=True)
duration_s.sort_values(ascending=False, inplace=True)
energy.sort_values(ascending=False, inplace=True)
instrumentalness.sort_values(ascending=False, inplace=True)
loudness.sort_values(ascending=False, inplace=True)
speechiness.sort_values(ascending=False, inplace=True)
tempo.sort_values(ascending=False, inplace=True)
valence.sort_values(ascending=False, inplace=True)

# %% [markdown]
# Some average values per genre

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(20,30))

danceability.plot(ax=axes[0,0], kind='bar', rot=45, title="Avg danceability per genre", colormap='PRGn')
duration_s.plot(ax=axes[0,1], kind='bar', rot=45, title="Avg duration(s) per genre", colormap='BrBG')
energy.plot(ax=axes[1,0], kind='bar', rot=45, title="Avg energy per genre", colormap='Wistia')
instrumentalness.plot(ax=axes[1,1], kind='bar', rot=45, title="Avg instrumentalness per genre", colormap='coolwarm')
loudness.plot(ax=axes[2,0], kind='bar', rot=45, title="Avg loudness(dB) per genre", colormap='PuOr')
speechiness.plot(ax=axes[2,1], kind='bar', rot=45, title="Avg speechiness per genre", colormap='RdGy')
tempo.plot(ax=axes[3,0], kind='bar', rot=45, title="Avg tempo per genre", colormap='winter')
for p in axes[3,0].patches:
    axes[3,0].annotate(str(int(p.get_height())), (p.get_x() * 1.01, p.get_height() * 1.01))
valence.plot(ax=axes[3,1], kind='bar', rot=45, title="Avg valence per genre", colormap='summer')


    
    
for ax_x in axes:
    for ax_y in ax_x:
        ax_y.xaxis.label.set_visible(False)
plt.subplots_adjust(hspace = 0.3)
plt.show()

# %%
#key, mode, time signature
keys_translation = {
    0: 'C', 
    1: 'C#/Db', 
    2: 'D',
    3: 'D#/Eb',
    4: 'E',
    5: 'F',
    6: 'F#/Gb',
    7: 'G',
    8: 'G#/Ab',
    9: 'A',
    10: 'A#/Bb',
    11: 'B'
}
mode_translation = {
    0: 'minor',
    1: 'major'
}
key_replaced = key.replace(keys_translation)
mode_replaced = mode.replace(mode_translation)

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,10))
key_replaced.value_counts().plot(ax=axes[0], kind='pie', title="Most used key per genre", colormap='PRGn', fontsize=15, autopct='%1.0f%%', pctdistance=1.15, labeldistance=1.3, labels = ['','','','','',''])
axes[0].legend(loc=3, labels=key_replaced.value_counts().index)

mode_replaced.value_counts().plot(ax=axes[1], kind='pie', title="Most used mode per genre", colormap='BrBG', fontsize=15, autopct='%1.0f%%', pctdistance=1.15, labeldistance=1.3, labels = [''])
axes[1].legend(loc=3, labels=mode_replaced.value_counts().index)

time_signature.value_counts().plot(ax=axes[2], kind='pie',  title="Most used quantity of beats per bar per genre", colormap='Wistia', fontsize=15, autopct='%1.0f%%', pctdistance=1.15, labeldistance=1.4, labels = [''])
axes[2].legend(loc=3, labels=time_signature.value_counts().index)

for ax in axes:
    ax.yaxis.label.set_visible(False)
plt.show()

# %% [markdown]
# Most used key in each genre

# %%
key_df = pd.DataFrame(key.replace(keys_translation))
key_df
# Out:
#               key
# genre
# country         G
# electronic      G
# folk            G
# jazz            F
# latin           C
# metal           D
# pop             C
# r&b         C#/Db
# rap         C#/Db
# rock            A

# %%
#TODO: seaborn mutual correlation, scatter plot it and see how it looks
#TODO: fijarme como sacar ratings y encontrar mercados nuevos o nuevos artistas
